# %%
import math


def sign_check(num):
    if num>0:
        return 1
    elif num<0:
        return -1
    elif num==0:
        return 0
    else: return None


def zero_fill_right_shift(val, n):
    return (val >> n) if val >= 0 else ((val + 0x100000000) >> n)

def dec2bin1(dec):
    return dec2bin((zero_fill_right_shift(dec, 0)))

# %%
def dec2bin(num):
    
    places = 52
    
    sign = 1
    
    if num<0:
        sign = -1
    
    num = abs(num)
    integer = bin(int(num))[2:]
    fraction = num - int(num) 
    counter = 1
    
    if fraction != 0:   
        bin_num = integer + "."
        while counter<=places:
            fraction = fraction*2        
            if fraction>=1:
                bin_num += '1'
                fraction-=1
            else:
                bin_num += '0'
            counter+=1
    else:
        bin_num = integer
    
    if sign== -1 :
        temp = ''
        for i in bin_num:
            if i == '0':
                i = '1'
            elif i== '1':
                i = '0'
            temp += i
        
        bin_num = bin_addition(temp,1)

    return bin_num

# %%
def calculatePositValue(binary, posit, expo):
    sign = 0
    regimesign = 0
    isRegime = True
    runlength = 0
    expo_bitvalue = 0
    fraction_bitvalue = 0
    fractionlength = 0
    i = int(binary, 2)
    INF = "1"
    j = len(binary) - 1
    
    while(j > 0):
        INF = INF + "0"
        j -= 1
    
    
    if binary == INF:
        value = "INF"

    elif i == 0:
        value = 0

    else:
        for j in range(len(binary)):
            if (j == 0):
                sign=int(binary[j])
                if sign == 0:
                    sign=1

                elif sign == 1:
                    sign=-1
                    # Two's complements
                    binary=dec2bin1(-i)[32-posit:32]
                    while(len(binary) < posit):
                        binary="0" + binary

            elif (j == 1):
                
                regimesign=int(binary[j])
                runlength += 1

            else:
                if (isRegime):
                    if(int(binary[j]) == regimesign):
                        runlength += 1

                    else:
                        isRegime=False
                        expo_start=runlength + 2
                        expoLength_max=expo_start + int(expo)
                        if (int(expo) > 0 and (expo_start) < len(binary)):
                            tmp_expo=binary[expo_start: len(binary)]

                            if (len(tmp_expo) > expo):
                                tmp_expo=tmp_expo[0: expo]


                            elif (len(tmp_expo) < expo):
                                missingzero=expo-len(tmp_expo)
                                while(missingzero > 0):
                                    tmp_expo += "0"
                                    missingzero -= 1


                            expo_bitvalue=int(tmp_expo, 2)


                        # Check fraction
                        if(expoLength_max < len(binary)):
                            fractionlength=len(binary) - expoLength_max
                            tmp_frac=binary[expoLength_max:len(binary)]
                            fraction_bitvalue=int(tmp_frac, 2)


                        break





        k=0

        if (regimesign == 0):
            k=-(runlength)

        else:
            k=runlength-1

        regime=pow(pow(2, pow(2, expo)), k)
        expo_value=pow(2, expo_bitvalue)
        fraction_max=pow(2, fractionlength)
        fraction_value=1 + (int(fraction_bitvalue)/fraction_max)
        value=sign * regime * expo_value * fraction_value



    return value

# %%
def plotPosit(n,es):
    y=[]
    x=[]
    for i in range(0,pow(2,n)):
        y.append(calculatePositValue(bin(i)[2:].rjust(n,'0'),n,es))
    return (y)

# %%
y = plotPosit(8,0)
y = [j/64 for j in y if(j!='INF')]

# %%
import matplotlib.pyplot as plt

# %%
import math
g=[]
h = []
for i in range(-128,126):
    g.append(1/(1+math.exp(-i)))
    h.append(i)
y1 = [y[i] for i in range(0,128)]
y2 = [y[i]+2 for i in range(129,255)]
plt.plot(h,[(y1+y2)[i]/2 for i in range(0,254)])
plt.plot(h,g)
plt.show()

# %%
k = [(y1+y2)[i]/2 for i in range(0,254)]

# %%
k
# Out:
# [0.0,
#  0.0001220703125,
#  0.000244140625,
#  0.0003662109375,
#  0.00048828125,
#  0.0006103515625,
#  0.000732421875,
#  0.0008544921875,
#  0.0009765625,
#  0.0010986328125,
#  0.001220703125,
#  0.0013427734375,
#  0.00146484375,
#  0.0015869140625,
#  0.001708984375,
#  0.0018310546875,
#  0.001953125,
#  0.0020751953125,
#  0.002197265625,
#  0.0023193359375,
#  0.00244140625,
#  0.0025634765625,
#  0.002685546875,
#  0.0028076171875,
#  0.0029296875,
#  0.0030517578125,
#  0.003173828125,
#  0.0032958984375,
#  0.00341796875,
#  0.0035400390625,
#  0.003662109375,
#  0.0037841796875,
#  0.00390625,
#  0.0040283203125,
#  0.004150390625,
#  0.0042724609375,
#  0.00439453125,
#  0.0045166015625,
#  0.004638671875,
#  0.0047607421875,
#  0.0048828125,
#  0.0050048828125,
#  0.005126953125,
#  0.0052490234375,
#  0.00537109375,
#  0.0054931640625,
#  0.005615234375,
#  0.0057373046875,
#  0.005859375,
#  0.0059814453125,
#  0.006103515625,
#  0.0062255859375,
#  0.00634765625,
#  0.0064697265625,
#  0.006591796875,
#  0.0067138671875,
#  0.0068359375,
#  0.0069580078125,
#  0.007080078125,
#  0.0072021484375,
#  0.00732421875,
#  0.0074462890625,
#  0.007568359375,
#  0.0076904296875,
#  0.0078125,
#  0.008056640625,
#  0.00830078125,
#  0.008544921875,
#  0.0087890625,
#  0.009033203125,
#  0.00927734375,
#  0.009521484375,
#  0.009765625,
#  0.010009765625,
#  0.01025390625,
#  0.010498046875,
#  0.0107421875,
#  0.010986328125,
#  0.01123046875,
#  0.011474609375,
#  0.01171875,
#  0.011962890625,
#  0.01220703125,
#  0.012451171875,
#  0.0126953125,
#  0.012939453125,
#  0.01318359375,
#  0.013427734375,
#  0.013671875,
#  0.013916015625,
#  0.01416015625,
#  0.014404296875,
#  0.0146484375,
#  0.014892578125,
#  0.01513671875,
#  0.015380859375,
#  0.015625,
#  0.0166015625,
#  0.017578125,
#  0.0185546875,
#  0.01953125,
#  0.0205078125,
#  0.021484375,
#  0.0224609375,
#  0.0234375,
#  0.0244140625,
#  0.025390625,
#  0.0263671875,
#  0.02734375,
#  0.0283203125,
#  0.029296875,
#  0.0302734375,
#  0.03125,
#  0.03515625,
#  0.0390625,
#  0.04296875,
#  0.046875,
#  0.05078125,
#  0.0546875,
#  0.05859375,
#  0.0625,
#  0.078125,
#  0.09375,
#  0.109375,
#  0.125,
#  0.1875,
#  0.25,
#  0.5,
#  0.75,
#  0.8125,
#  0.875,
#  0.890625,
#  0.90625,
#  0.921875,
#  0.9375,
#  0.94140625,
#  0.9453125,
#  0.94921875,
#  0.953125,
#  0.95703125,
#  0.9609375,
#  0.96484375,
#  0.96875,
#  0.9697265625,
#  0.970703125,
#  0.9716796875,
#  0.97265625,
#  0.9736328125,
#  0.974609375,
#  0.9755859375,
#  0.9765625,
#  0.9775390625,
#  0.978515625,
#  0.9794921875,
#  0.98046875,
#  0.9814453125,
#  0.982421875,
#  0.9833984375,
#  0.984375,
#  0.984619140625,
#  0.98486328125,
#  0.985107421875,
#  0.9853515625,
#  0.985595703125,
#  0.98583984375,
#  0.986083984375,
#  0.986328125,
#  0.986572265625,
#  0.98681640625,
#  0.987060546875,
#  0.9873046875,
#  0.987548828125,
#  0.98779296875,
#  0.988037109375,
#  0.98828125,
#  0.988525390625,
#  0.98876953125,
#  0.989013671875,
#  0.9892578125,
#  0.989501953125,
#  0.98974609375,
#  0.989990234375,
#  0.990234375,
#  0.990478515625,
#  0.99072265625,
#  0.990966796875,
#  0.9912109375,
#  0.991455078125,
#  0.99169921875,
#  0.991943359375,
#  0.9921875,
#  0.9923095703125,
#  0.992431640625,
#  0.9925537109375,
#  0.99267578125,
#  0.9927978515625,
#  0.992919921875,
#  0.9930419921875,
#  0.9931640625,
#  0.9932861328125,
#  0.993408203125,
#  0.9935302734375,
#  0.99365234375,
#  0.9937744140625,
#  0.993896484375,
#  0.9940185546875,
#  0.994140625,
#  0.9942626953125,
#  0.994384765625,
#  0.9945068359375,
#  0.99462890625,
#  0.9947509765625,
#  0.994873046875,
#  0.9949951171875,
#  0.9951171875,
#  0.9952392578125,
#  0.995361328125,
#  0.9954833984375,
#  0.99560546875,
#  0.9957275390625,
#  0.995849609375,
#  0.9959716796875,
#  0.99609375,
#  0.9962158203125,
#  0.996337890625,
#  0.9964599609375,
#  0.99658203125,
#  0.9967041015625,
#  0.996826171875,
#  0.9969482421875,
#  0.9970703125,
#  0.9971923828125,
#  0.997314453125,
#  0.9974365234375,
#  0.99755859375,
#  0.9976806640625,
#  0.997802734375,
#  0.9979248046875,
#  0.998046875,
#  0.9981689453125,
#  0.998291015625,
#  0.9984130859375,
#  0.99853515625,
#  0.9986572265625,
#  0.998779296875,
#  0.9989013671875,
#  0.9990234375,
#  0.9991455078125,
#  0.999267578125,
#  0.9993896484375,
#  0.99951171875,
#  0.9996337890625,
#  0.999755859375,
#  0.9998779296875]
